# %%
import os
import certifi
import pymongo
import pandas as pd

ca = certifi.where()

MONGO_DB_URL = "mongodb+srv://sparshshakya2004_db_user:JY09CWtnommoOwHO@cluster0.arbefhm.mongodb.net/?appName=Cluster0"
DATABASE_NAME ="phising-classifier"
DATASETS_DIR = r"F:\Semister 5th\ML Tranning project\upload_data_to_db\ipynb_checkpoints"

try :
    client = pymongo.MongoClient(MONGO_DB_URL , tlsCAFile = ca )
    database = client[DATABASE_NAME]
    print("Connected to MongoDB ATLAS")
except Exception as e:
    raise Exception(f"MongoDB connection failed : {e}")
# Out:
# Connected to MongoDB ATLAS

# %%
def upload_files_to_mongodb(dataset_dir):
    for file in os.listdir(dataset_dir):
        if file.endswith('.csv'):
            collection_name = file.split(',')[0]
            collection = database[collection_name]

            file_path = os.path.join(dataset_dir, file)
            print(f"processing file : {file_path}")

            df = pd.read_csv(file_path)
            df.columns = df.columns.str.strip()
            df.astype(str)
            data = df.to_dict(orient= "records")

            if data:
                collection.insert_many(data)
                print(f"{len(data)} record uploded to collection : {collection_name} ")
            else : 
                print(f"No data found in {file}")


upload_files_to_mongodb(DATASETS_DIR)
# Out:
# processing file : F:\Semister 5th\ML Tranning project\upload_data_to_db\ipynb_checkpoints\phising.csv
# 11055 record uploded to collection : phising.csv
